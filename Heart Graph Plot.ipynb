# %% [markdown]
# Name : Aishwarya Avinash Nikam
# Div: TEITA
# Roll No. : 35058
# Batch : C

# %% [markdown]
# # Problem Statement
#
# Visualize the data using Python libraries matplotlib, seaborn by plotting the graphs for
# Heart disease dataset.( Charts : Line chart, Barplot, Heatmap, Scatterplot, histogram,
# boxplot, violin, timeseries chart)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as ply

# %%
df=pd.read_csv(r"C:\Users\aishn\Desktop\DSBDAL\Datasets\heart.csv" , sep=',')
df
# Out:
#      age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0     63    1   3     145   233    1        0       150     0      2.3    0
# 1     37    1   2     130   250    0        1       187     0      3.5    0
# 2     41    0   1     130   204    0        0       172     0      1.4    2
# 3     56    1   1     120   236    0        1       178     0      0.8    2
# 4     57    0   0     120   354    0        1       163     1      0.6    2
# ..   ...  ...  ..     ...   ...  ...      ...       ...   ...      ...  ...
# 298   57    0   0     140   241    0        1       123     1      0.2    1
# 299   45    1   3     110   264    0        1       132     0      1.2    1
# 300   68    1   0     144   193    1        1       141     0      3.4    1
# 301   57    1   0     130   131    0        1       115     1      1.2    1
# 302   57    0   1     130   236    0        0       174     0      0.0    1
#
#      caa  thall  output
# 0      0      1       1
# ...

# %%
#barplot
ply.figure(figsize=(20,5))
sns.barplot(x='age',y='cp' ,hue='sex', data= df)
# Out:
# <AxesSubplot:xlabel='age', ylabel='cp'>

# %%
#barplot
ply.figure(figsize=(20,5))
sns.barplot(x='age',y='cp' , data= df)
# Out:
# <AxesSubplot:xlabel='age', ylabel='cp'>

# %%
#barplot

ply.figure(figsize=(20,5))
ply.bar(df['age'], df['cp'])
# Out:
# <BarContainer object of 303 artists>

# %%
#Line Plot Using Seaborn

x=df['age']
y=df['cp']
sns.lineplot(x,y)
# Out:
# C:\Users\Gaurav\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='age', ylabel='cp'>

# %%
#Line Plot Using Seaborn

x=df['sex']
y=df['cp']
sns.lineplot(x,y)
# Out:
# C:\Users\Gaurav\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='sex', ylabel='cp'>

# %%
#Lineplot Using Plyplot

x=df['sex']
y=df['cp']
ply.plot(x,y , linestyle = '-',marker='o')

# %%
#Lineplot Using Plyplot

x=df['age']
y=df['cp']
ply.plot(x,y , linestyle = '-',marker='o')

# %%
#Lineplot Using Plyplot

x=df['age']
y=df['trtbps']
ply.plot(x,y , linestyle = '-',marker='o')

# %%
#heat map using seaborn

ply.figure(figsize=(12,10))
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %%
#SCATTERPLOT using MATPLOTLIB

x=df['age']
y=df['trtbps']
ply.scatter(x,y, alpha=0.5)

# %%
#SCATTERPLOT using SEABORN

x=df['age']
y=df['trtbps']
sns.scatterplot(x,y)
# Out:
# C:\Users\Gaurav\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='age', ylabel='trtbps'>

# %%
#HISTOGRAM using MATPLOTLIB

x=df['age']
ply.hist(x)
# Out:
# (array([ 1., 11., 33., 38., 37., 60., 63., 43., 14.,  3.]),
#  array([29. , 33.8, 38.6, 43.4, 48.2, 53. , 57.8, 62.6, 67.4, 72.2, 77. ]),
#  <BarContainer object of 10 artists>)

# %%
#HISTOGRAM using MATPLOTLIB

x=df['cp']
ply.hist(x)
# Out:
# (array([143.,   0.,   0.,  50.,   0.,   0.,  87.,   0.,   0.,  23.]),
#  array([0. , 0.3, 0.6, 0.9, 1.2, 1.5, 1.8, 2.1, 2.4, 2.7, 3. ]),
#  <BarContainer object of 10 artists>)

# %%
#TREEMAP

import squarify

x=df['RestBP']
squarify.plot(x)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [45], in <cell line: 1>()
# ----> 1 import squarify
#
# ModuleNotFoundError: No module named 'squarify'

# %%
#BOXPLOT using SEABORN

#ply.figure(figsize=(15,5))
x=df['sex']
y=df['cp']
sns.boxplot(x,y)
# Out:
# C:\Users\Gaurav\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='sex', ylabel='cp'>

# %%
#BOXPLOT using SEABORN

ply.figure(figsize=(15,5))
x=df['age']
y=df['chol']
sns.boxplot(x,y)
# Out:
# C:\Users\Gaurav\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='age', ylabel='chol'>

# %%
#BOXPLOT using SEABORN

ply.figure(figsize=(20,5))
sns.boxplot(x = "age", y = "cp", hue = "sex", data = df);

# %%
#violinplot using seaborn

ply.figure(figsize=(20,5))
sns.violinplot(x ="age", y = "cp", hue = "sex", data = df);

# %%
#VIOLINPLOT using SEABORN


x=df['age']
sns.violinplot(x)
# Out:
# C:\Users\Gaurav\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='age'>
