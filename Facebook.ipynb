# %%
Name : Aishwarya Avinash Nikam
Div: TEITA
Roll No. : 35058
Batch : C

# %% [markdown]
# # Problem Statement:
# Perform the following operations using Python on the Facebook metrics data sets
#
#     a. Create data subsets b. Merge data c. Sort data d. Transposing Data e. Shape and reshape Data

# %%
import pandas as pd
import numpy as np

df=pd.read_csv(r'C:\Users\Gaurav\Desktop\DSBDAL\Datasets\dataset_Facebook.csv' ,sep=';')

# %%
df
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %%
df.head()
# Out:
#    Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0            139441   Photo         2          12             4          3
# 1            139441  Status         2          12             3         10
# 2            139441   Photo         3          12             3          3
# 3            139441   Photo         2          12             2         10
# 4            139441   Photo         2          12             2          3
#
#    Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0   0.0                       2752                             5091
# 1   0.0                      10460                            19057
# 2   0.0                       2413                             4373
# 3   1.0                      50128                            87991
# 4   0.0                       7244                            13594
#
#    Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %%
df.describe()
# Out:
#        Page total likes    Category  Post Month  Post Weekday   Post Hour  \
# count        500.000000  500.000000  500.000000    500.000000  500.000000
# mean      123194.176000    1.880000    7.038000      4.150000    7.840000
# std        16272.813214    0.852675    3.307936      2.030701    4.368589
# min        81370.000000    1.000000    1.000000      1.000000    1.000000
# 25%       112676.000000    1.000000    4.000000      2.000000    3.000000
# 50%       129600.000000    2.000000    7.000000      4.000000    9.000000
# 75%       136393.000000    3.000000   10.000000      6.000000   11.000000
# max       139441.000000    3.000000   12.000000      7.000000   23.000000
#
#              Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# count  499.000000                  500.00000                     5.000000e+02
# mean     0.278557                13903.36000                     2.958595e+04
# ...

# %%
df['Type']
# Out:
# 0       Photo
# 1      Status
# 2       Photo
# 3       Photo
# 4       Photo
#         ...
# 495     Photo
# 496     Photo
# 497     Photo
# 498     Photo
# 499     Photo
# Name: Type, Length: 500, dtype: object

# %%
df.columns
# Out:
# Index(['Page total likes', 'Type', 'Category', 'Post Month', 'Post Weekday',
#        'Post Hour', 'Paid', 'Lifetime Post Total Reach',
#        'Lifetime Post Total Impressions', 'Lifetime Engaged Users',
#        'Lifetime Post Consumers', 'Lifetime Post Consumptions',
#        'Lifetime Post Impressions by people who have liked your Page',
#        'Lifetime Post reach by people who like your Page',
#        'Lifetime People who have liked your Page and engaged with your post',
#        'comment', 'like', 'share', 'Total Interactions'],
#       dtype='object')

# %%
df[['Type','Category']]
# Out:
#        Type  Category
# 0     Photo         2
# 1    Status         2
# 2     Photo         3
# 3     Photo         2
# 4     Photo         2
# ..      ...       ...
# 495   Photo         3
# 496   Photo         2
# 497   Photo         1
# 498   Photo         3
# 499   Photo         2
#
# [500 rows x 2 columns]

# %% [markdown]
# Create Subsets

# %%
df.shape
# Out:
# (500, 19)

# %% [markdown]
# # Create Subset

# %%
df_subset1 = df[df['like']>100]
df_subset1
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 1              139441  Status         2          12             3         10
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# 5              139441  Status         2          12             1          9
# 6              139441   Photo         3          12             1          3
# ..                ...     ...       ...         ...           ...        ...
# 488             85979   Photo         3           1             7         10
# 491             85979   Photo         3           1             6          3
# 492             85979    Link         1           1             5         11
# 493             85093   Photo         3           1             1          2
# 494             85093   Photo         3           1             7         10
#
# ...

# %%
df_subset2=df[['Page total likes','Category','Post Month','Post Weekday']].loc[0:20]
df_subset2
# Out:
#     Page total likes  Category  Post Month  Post Weekday
# 0             139441         2          12             4
# 1             139441         2          12             3
# 2             139441         3          12             3
# 3             139441         2          12             2
# 4             139441         2          12             2
# 5             139441         2          12             1
# 6             139441         3          12             1
# 7             139441         3          12             7
# 8             139441         2          12             7
# 9             139441         3          12             6
# 10            139441         2          12             5
# 11            139441         2          12             5
# 12            139441         2          12             5
# 13            139441         2          12             5
# 14            138414         2          12             4
# ...

# %%
df_subset3=df[['Page total likes','Category','Post Month','Post Weekday','Paid','like']].loc[21:40]
df_subset3
# Out:
#     Page total likes  Category  Post Month  Post Weekday  Paid   like
# 21            138414         1          12             7   0.0    0.0
# 22            138414         1          12             7   0.0   16.0
# 23            138414         3          12             7   0.0   72.0
# 24            138414         2          12             6   0.0   99.0
# 25            138458         2          12             6   0.0   88.0
# 26            138458         2          12             5   0.0  412.0
# 27            138458         3          12             5   0.0  100.0
# 28            138895         2          12             5   0.0  523.0
# 29            138895         1          12             4   1.0  143.0
# 30            138895         2          12             4   0.0  107.0
# 31            138895         2          12             3   0.0   27.0
# 32            138895         3          12             3   0.0  155.0
# ...

# %% [markdown]
# # Merge Data

# %%
merge1=pd.concat([df_subset2,df_subset3])
merge1
# Out:
#     Page total likes  Category  Post Month  Post Weekday  Paid   like
# 0             139441         2          12             4   NaN    NaN
# 1             139441         2          12             3   NaN    NaN
# 2             139441         3          12             3   NaN    NaN
# 3             139441         2          12             2   NaN    NaN
# 4             139441         2          12             2   NaN    NaN
# 5             139441         2          12             1   NaN    NaN
# 6             139441         3          12             1   NaN    NaN
# 7             139441         3          12             7   NaN    NaN
# 8             139441         2          12             7   NaN    NaN
# 9             139441         3          12             6   NaN    NaN
# 10            139441         2          12             5   NaN    NaN
# 11            139441         2          12             5   NaN    NaN
# ...

# %% [markdown]
# # Sort Data

# %%
df.sort_values(by= 'Category')
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 128            136393  Photo         1          10             6         13
# 144            136013  Photo         1          10             2          3
# 145            136013  Photo         1          10             1         10
# 402            107907  Photo         1           4             3          4
# 401            107907  Photo         1           4             3         13
# ..                ...    ...       ...         ...           ...        ...
# 356            116435  Photo         3           5             1         13
# 359            116091  Photo         3           5             7          2
# 361            116091  Photo         3           5             6          3
# 143            136013  Photo         3          10             2         10
# 162            135617  Photo         3           9             6         10
#
# ...

# %%
df
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %% [markdown]
# # Transpose Data

# %%
transposing = df.transpose()
transposing
# Out:
#                                                        0       1       2    \
# Page total likes                                    139441  139441  139441
# Type                                                 Photo  Status   Photo
# Category                                                 2       2       3
# Post Month                                              12      12      12
# Post Weekday                                             4       3       3
# Post Hour                                                3      10       3
# Paid                                                   0.0     0.0     0.0
# Lifetime Post Total Reach                             2752   10460    2413
# Lifetime Post Total Impressions                       5091   19057    4373
# Lifetime Engaged Users                                 178    1457     177
# Lifetime Post Consumers                                109    1361     113
# ...

# %% [markdown]
# # Reshaping

# %%
shaping=df.shape
shaping
# Out:
# (500, 19)

# %%
pivot_table=pd.pivot_table(df,index=['Type','Category'],values='like')
pivot_table
# Out:
#                        like
# Type   Category
# Link   1          75.650000
#        2          32.000000
#        3          68.000000
# Photo  1         126.000000
#        2         235.857143
#        3         219.753333
# Status 1         136.333333
#        2         182.552632
#        3         151.500000
# Video  1         231.428571

# %% [markdown]
# # Reshaping from wide to long

# %%
pd.melt(df,id_vars=['Type'],value_vars=['like'])
# Out:
#        Type variable   value
# 0     Photo     like    79.0
# 1    Status     like   130.0
# 2     Photo     like    66.0
# 3     Photo     like  1572.0
# 4     Photo     like   325.0
# ..      ...      ...     ...
# 495   Photo     like    53.0
# 496   Photo     like    53.0
# 497   Photo     like    93.0
# 498   Photo     like    91.0
# 499   Photo     like    91.0
#
# [500 rows x 3 columns]
